# %% [markdown]
# <a href="https://colab.research.google.com/github/YunTaeHyeon/AILab/blob/main/tytanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.show()

# %%
import csv
f=open('train.csv')
rdr=csv.reader(f)

for line in rdr:
  print(line)
  break
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
import csv
import matplotlib.pyplot as plt

f=open('train.csv')
rdr=csv.reader(f)

sexCount=0
count=0

for line in rdr:
    if 'female' in line:
      sexCount+=1
    count+=1
    plt.plot(count,sexCount,'b.')  
plt.show()

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

tytanic=pd.read_csv('train.csv')

name=tytanic[['Name','Age','Cabin']]
name
# Out:
#                                                   Name   Age Cabin
# 0                              Braund, Mr. Owen Harris  22.0   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0   C85
# 2                               Heikkinen, Miss. Laina  26.0   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  C123
# 4                             Allen, Mr. William Henry  35.0   NaN
# ..                                                 ...   ...   ...
# 886                              Montvila, Rev. Juozas  27.0   NaN
# 887                       Graham, Miss. Margaret Edith  19.0   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN   NaN
# 889                              Behr, Mr. Karl Howell  26.0  C148
# 890                                Dooley, Mr. Patrick  32.0   NaN
#
# [891 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

rdr = pd.read_csv("train.csv",header=None)

label=[] #생존한 사람 데이터
data=[] #생존했는지 판별에 필요한 데이터
sv=[]

for row_index, row in rdr.iterrows():
  #print(row_index)
  #print(row)
  label.append(row.loc[1]) #승객 번호는 관계없음
  other_data=[]
  for v in row.loc[2:]:
    other_data.append(v)
  data.append(other_data)

pclass1=0
pclass2=0
pclass3=0
pcount=0

for sv in range(len(label[1:])):
  if label[sv]=='1':
    if data[sv][0] == '1':
      pclass1+=1
    elif data[sv][0] == '2':
      pclass2+=1
    elif data[sv][0] == '3':
      pclass3+=1
  pcount+=1

x=np.arange(3)
xvalue=[1,2,3]
yvalue=[pclass1/pcount,pclass2/pcount,pclass3/pcount]

plt.bar(x, yvalue)
plt.xticks(x,xvalue)

plt.show()

# %%
a=df['Age']

a=a.sort_values(ascending=True)
a = a.dropna(axis=0, inplace=False)
#중간값 38.0이니까 20씩 나눠서 그래프
count=0
sum1=0


a1=df [ df['Age'] <= 10 ]
a2=df [ df['Age'] <= 20 ]
a3=df [ df['Age'] <= 30 ]
a4=df [ df['Age'] <= 40 ]
a5=df [ df['Age'] <= 50 ]
a6=df [ df['Age'] <= 60 ]
a7=df [ df['Age'] <= 70 ]
a8=df [ df['Age'] <= 80 ]

a8 = pd.merge(a8,a7, how="outer")
a7 = pd.merge(a7,a6, how="outer")
a6 = pd.merge(a6,a5, how="outer")
a5 = pd.merge(a5,a4, how="outer")
a4 = pd.merge(a4,a3, how="outer")
a3 = pd.merge(a3,a2, how="outer")
a2 = pd.merge(a2,a1, how="outer")

b=df [df['Survived'] == 1]

d1 = pd.merge(a1, b)
d2 = pd.merge(a2, b)
d3 = pd.merge(a3, b)
d4 = pd.merge(a4, b)
d5 = pd.merge(a5, b)
d6 = pd.merge(a6, b)
d7 = pd.merge(a7, b)
d8 = pd.merge(a8, b)


x=np.arange(8)
xvalue=[1,2,3,4,5,6,7,8]
yvalue=[len(d1)/len(a1),len(d2)/len(a2),len(d3)/len(a3),len(d4)/len(a4),
len(d5)/len(a5),len(d6)/len(a6),len(d7)/len(a7),len(d8)/len(a8)]

plt.bar(x, yvalue)
plt.xticks(x,xvalue)

plt.show()

# %%
df['Passenger'] = df['SibSp'] + df['Parch']

p=df['Passenger']
#print(max(p.values)) 동승자 최대 인원은 10명
# 8명 7명은 표본이 없어서 동승자가 있거나 없거나로 분류



s=df[df['Survived']==1]

p1=pd.merge(df[df['Passenger'] ==0],s)
p2=pd.merge(df[df['Passenger'] !=0],s)

a=p1.size/df[df['Passenger']==0].size
b=p2.size/df[df['Passenger']!=0].size

x=np.arange(2)
xvalue=[0,1]
yvalue=[a,b]

plt.bar(x, yvalue)
plt.xticks(x,xvalue)

plt.show()

# %%
aLivingCount=0
bLivingCount=0
aCount=0
bCount=0
count=0

#print(df['Ticket'].values[1][0].isalpha())

for i in range(len(df['Ticket'])):
  if df['Ticket'].values[i][0].isalpha() == True: #티켓이 알파벳으로 시작하는 경우
    aCount+=1
  else:
    bCount+=1

  if df['Survived'][i]==1:
    if df['Ticket'].values[i][0].isalpha() == True: #티켓이 알파벳으로 시작하는데 살아남은 경우
      aLivingCount+=1
    else:
      bLivingCount+=1
    count+=1
      #print(df['Survived'][i])
      #print(df['Ticket'].values[i][0])
      #print()


x=np.arange(2)
xvalue=[0,1]
yvalue=[aLivingCount/aCount,bLivingCount/bCount]

plt.bar(x, yvalue)
plt.xticks(x,xvalue)

plt.show()
#for i in range(len(a)):
#  if a[i][0].isalpha():

# %%
#for i in range(len(df['Ticket'])):
#  df['Ticket'][i] = df['Ticket'][i].replace(" ", "")

test=pd.DataFrame(df['Ticket'].tolist())


#print(df['Ticket'])

# row 생략 없이 출력
pd.set_option('display.max_rows', None)
# col 생략 없이 출력
pd.set_option('display.max_columns', None)

#print(test.value_counts()==1)
count=0
aCount=0
bCount=0

print(len(test.value_counts()))

for i in range(len(test.value_counts())):
  if test.value_counts()[i]==1:
    aCount+=1
  else:
    bCount=bCount+test.value_counts()[i]
print(test.value_counts())


count=aCount+bCount

print(aCount)
print(bCount)
print(count)

# %%
from sklearn import preprocessing

def encode_features(dataDF):
  features = ['Cabin','Sex','Embarked']
  for feature in features:
    le=preprocessing.LabelEncoder()
    le=le.fit(dataDF[feature])
    dataDF[feature]=le.transform(dataDF[feature])

    return dataDF

df=encode_features(df)
df.head()

#이하는 다 직접 해보기
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Cabin Embarked  Passenger
# 0      0         A/5 21171   7.2500    147        S          1
# 1      0          PC 17599  71.2833     81        C          1
# 2      0  STON/O2. 3101282   7.9250    147        S          0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.base import BaseEstimator

df=pd.read_csv('train.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
print('데이터 정보\n')
print(df.info()) #dataframe의 데이터 정보 불러옴
# Out:
# 데이터 정보
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
#fillna NaN값 함수 인자값으로 대체
#inplace=True 데이터프레임 정렬된 결과로 바뀜 return None
#inplace=False면 정렬되지 않음

df['Cabin'].fillna('N',inplace=True)
df['Embarked'].fillna('N',inplace=True)

print('데이터 세트 NaN값 개수',df.isnull().sum().sum())
#sum() 한번만 쓰면 각각의 key에서의 NaN 개수 확인 가능
# Out:
# 데이터 세트 NaN값 개수 0

# %%
print(df['Sex'].value_counts())
print(df['Cabin'].value_counts())
print(df['Embarked'].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# N                  687
# C23 C25 C27          4
# G6                   4
# B96 B98              4
# C22 C26              3
# D                    3
# F33                  3
# E101                 3
# F2                   3
# B20                  2
# E67                  2
# C125                 2
# E24                  2
# B49                  2
# B77                  2
# D35                  2
# C78                  2
# C93                  2
# C65                  2
# B57 B59 B63 B66      2
# B5                   2
# E121                 2
# B51 B53 B55          2
# B18                  2
# C124                 2
# C126                 2
# B35                  2
# E44                  2
# C92                  2
# C68                  2
# D20                  2
# B22                  2
# E25                  2
# D36                  2
# E8                   2
# C83                  2
# C2                   2
# ...

# %%
df['Cabin']=df['Cabin'].str[0] #str 표시 필수
print(df['Cabin'].head()) #인자 설정 안할 경우 default=5 맨 처음 5줄 보여줌 tail도 있음
df['Cabin'].value_counts()
# Out:
# 0    N
# 1    C
# 2    N
# 3    C
# 4    N
# Name: Cabin, dtype: object
# N    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin, dtype: int64

# %%
def get_Category(age):
  cat = ''
  if age<=10: cat='case1'
  elif age<=20: cat='case2'
  elif age<=30: cat='case3'
  elif age<=40: cat='case4'
  elif age<=50: cat='case5'
  elif age<=60: cat='case6'
  elif age<=70: cat='case7'
  elif age<=80: cat='case8'

  return cat

group_names=['case1','case2','case3'
            ,'case4','case5','case6'
            ,'case7','case8'] 
#x축 값을 순차적으로 표시하기 위함

df['Age_cat']=df['Age'].apply(lambda x:get_Category(x))
#람다식으로 함수에서 받아온 리턴 값을 새롭게 적용

df.drop('Age_cat',axis=1,inplace=True) #axis=1 열 삭제

# %%
from sklearn.preprocessing import LabelEncoder

def encode_features(dataDF):
  features = ['Cabin','Sex','Embarked']
  for feature in features:
    le=preprocessing.LabelEncoder()
    le=le.fit(dataDF[feature])
    dataDF[feature]=le.transform(dataDF[feature])

    return dataDF

df=encode_features(df)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Cabin Embarked
# 0      0         A/5 21171   7.2500    147        S
# 1      0          PC 17599  71.2833     81        C
# 2      0  STON/O2. 3101282   7.9250    147        S
# 3      0            113803  53.1000     55        S
# 4      0            373450   8.0500    147        S

# %%
from sklearn.base import BaseEstimator
import numpy as np

class MyDummyClassifier(BaseEstimator):
    # fit() 메서드는 아무것도 학습하지 않음
    def fit(self, X, y=None):
        pass
    
    # predict() 메서드는 단순히 Sex가 1이면 0, 그렇지 않으면 1로 예측함.
    def predict(self, X):
        pred = np.zeros((X.shape[0], 1))
        for i in range(X.shape[0]):
            if X['Sex'].iloc[i] == 1:
                pred[i] = 0
            else:
                pred[i] = 1
                
        return pred

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Null 처리 함수
def fillna(df):
    df['Age'].fillna(df['Age'].mean(),inplace=True)
    df['Cabin'].fillna('N',inplace=True)
    df['Embarked'].fillna('N',inplace=True)
    df['Fare'].fillna(0,inplace=True)
    return df

# 머신러닝 알고리즘에 불필요한 속성 제거
def drop_features(df):
    df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)
    return df

# 레이블 인코딩 수행. 
def format_features(df):
    df['Cabin'] = df['Cabin'].str[:1]
    features = ['Cabin','Sex','Embarked']
    for feature in features:
        le = LabelEncoder()
        le = le.fit(df[feature])
        df[feature] = le.transform(df[feature])
    return df

# 앞에서 설정한 Data Preprocessing 함수 호출
def transform_features(df):
    df = fillna(df)
    df = drop_features(df)
    df = format_features(df)
    return df

# %%
df=pd.read_csv('train.csv')
y_df=df['Survived']
x_df=df.drop('Survived',axis=1)

x_df=transform_features(x_df)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x_df,y_df,\
                                               test_size=0.2,random_state=11)

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

dt_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()

dt_clf.fit(x_train,y_train)
dt_pred = dt_clf.predict(x_test)
print(format(accuracy_score(y_test,dt_pred)))
# Out:
# 0.7877094972067039
